# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
db = client.cuore_thermalmodeldata

import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pylab import *

from eventGenerator import *

# %%
#define constants

testNumber = 1;

alpha = [2.7e-8,9.9e-9,1e-11,9.14e3,4.28e-7,0]
beta = [3,4.37,2.4,3,2.4,2,1]
k = [2.34e-3,1.4,3.2e-5,1.3e-3,3.2e-5,2.5e-5,4e-7]

R0 = 3.2
s = .015
Rl = 6e10
T0 = 5.2
gamma = 0.5
Vb = 5
Cp = 5e-10

num = 10
for i in range(1,num):
    T0 = np.random.normal(5.6, 0.3)
    R0 = np.random.normal(3, 0.5)
    result = db.testdata.insert_one(getTemps(testNumber, 'crystal', alpha, beta, k, s, R0, Rl, T0, gamma, Vb, Cp))
    print result.inserted_id
# Out:
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.49E+00 |
# |          R0 | 3.71E+00 |
# +-------------+----------+
# Crystal Event
# 5a235931365e003e01a0495d
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.90E+00 |
# |          R0 | 2.47E+00 |
# +-------------+----------+
# Crystal Event
# 5a2359dc365e003e01a0495e
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.46E+00 |
# |          R0 | 2.96E+00 |
# +-------------+----------+
# Crystal Event
# 5a235a88365e003e01a0495f
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.72E+00 |
# |          R0 | 2.81E+00 |
# +-------------+----------+
# Crystal Event
# 5a235b34365e003e01a04960
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.79E+00 |
# |          R0 | 3.34E+00 |
# +-------------+----------+
# Crystal Event
# 5a235be3365e003e01a04961
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.39E+00 |
# |          R0 | 3.26E+00 |
# +-------------+----------+
# Crystal Event
# 5a235c8d365e003e01a04962
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 6.04E+00 |
# |          R0 | 1.83E+00 |
# +-------------+----------+
# Crystal Event
# 5a235d40365e003e01a04963
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.93E+00 |
# |          R0 | 2.77E+00 |
# +-------------+----------+
# Crystal Event
# 5a235def365e003e01a04964
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.63E+00 |
# |          R0 | 3.38E+00 |
# +-------------+----------+
# Crystal Event
# 5a235ea0365e003e01a04965

# %%
#define constants

testNumber = 2;

alpha = [2.7e-8,9.9e-9,1e-11,9.14e3,4.28e-7,0]
beta = [3,4.37,2.4,3,2.4,2,1]
k = [2.34e-3,1.4,3.2e-5,1.3e-3,3.2e-5,2.5e-5,4e-7]

R0 = 3.2
s = .015
Rl = 6e10
T0 = 5.2
gamma = 0.5
Vb = 5
Cp = 5e-10

num = 10
for t in [0.014,0.0145,0.015,0.0155,0.016]:
    for i in range(1,num):
        T0 = np.random.normal(5.6, 0.3)
        R0 = np.random.normal(3, 0.5)
        result = db.testdata.insert_one(getTemps(testNumber, 'crystal', alpha, beta, k, t, R0, Rl, T0, gamma, Vb, Cp))
        print result.inserted_id
# Out:
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 5.42E+00 |
# |          R0 | 2.82E+00 |
# +-------------+----------+
# Crystal Event
# 5a236169365e003e01a04967
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 6.15E+00 |
# |          R0 | 2.79E+00 |
# +-------------+----------+
# Crystal Event
# 5a236216365e003e01a04968
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 5.57E+00 |
# |          R0 | 3.12E+00 |
# +-------------+----------+
# Crystal Event
# 5a2362c8365e003e01a04969
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 6.23E+00 |
# |          R0 | 2.84E+00 |
# +-------------+----------+
# Crystal Event
# 5a236379365e003e01a0496a
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 5.72E+00 |
# |          R0 | 3.17E+00 |
# +-------------+----------+
# Crystal Event
# 5a23642f365e003e01a0496b
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 5.67E+00 |
# |          R0 | 2.70E+00 |
# +-------------+----------+
# Crystal Event
# 5a2364e4365e003e01a0496c
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 5.12E+00 |
# |          R0 | 2.74E+00 |
# +-------------+----------+
# Crystal Event
# 5a236598365e003e01a0496d
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 5.24E+00 |
# |          R0 | 2.75E+00 |
# +-------------+----------+
# Crystal Event
# 5a23664a365e003e01a0496e
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.40E-02 |
# |          T0 | 5.78E+00 |
# |          R0 | 3.12E+00 |
# +-------------+----------+
# Crystal Event
# 5a2366fe365e003e01a0496f
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.59E+00 |
# |          R0 | 3.09E+00 |
# +-------------+----------+
# Crystal Event
# 5a2367ad365e003e01a04970
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.45E+00 |
# |          R0 | 2.57E+00 |
# +-------------+----------+
# Crystal Event
# 5a236860365e003e01a04971
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.90E+00 |
# |          R0 | 3.30E+00 |
# +-------------+----------+
# Crystal Event
# 5a236917365e003e01a04972
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.40E+00 |
# |          R0 | 3.24E+00 |
# +-------------+----------+
# Crystal Event
# 5a2369cb365e003e01a04973
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.95E+00 |
# |          R0 | 3.64E+00 |
# +-------------+----------+
# Crystal Event
# 5a236a7e365e003e01a04974
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.44E+00 |
# |          R0 | 3.57E+00 |
# +-------------+----------+
# Crystal Event
# 5a236b33365e003e01a04975
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.19E+00 |
# |          R0 | 1.88E+00 |
# +-------------+----------+
# Crystal Event
# 5a236be4365e003e01a04976
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.62E+00 |
# |          R0 | 2.82E+00 |
# +-------------+----------+
# Crystal Event
# 5a236c95365e003e01a04977
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.45E-02 |
# |          T0 | 5.32E+00 |
# |          R0 | 2.22E+00 |
# +-------------+----------+
# Crystal Event
# 5a236d49365e003e01a04978
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.72E+00 |
# |          R0 | 2.26E+00 |
# +-------------+----------+
# Crystal Event
# 5a236df8365e003e01a04979
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.50E+00 |
# |          R0 | 3.33E+00 |
# +-------------+----------+
# Crystal Event
# 5a236eaf365e003e01a0497a
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.26E+00 |
# |          R0 | 2.64E+00 |
# +-------------+----------+
# Crystal Event
# 5a236f67365e003e01a0497b
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.50E+00 |
# |          R0 | 2.89E+00 |
# +-------------+----------+
# Crystal Event
# 5a23701d365e003e01a0497c
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.77E+00 |
# |          R0 | 3.03E+00 |
# +-------------+----------+
# Crystal Event
# 5a2370d4365e003e01a0497d
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.82E+00 |
# |          R0 | 3.28E+00 |
# +-------------+----------+
# Crystal Event
# 5a23718c365e003e01a0497e
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.66E+00 |
# |          R0 | 3.13E+00 |
# +-------------+----------+
# Crystal Event
# 5a237241365e003e01a0497f
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 6.09E+00 |
# |          R0 | 3.58E+00 |
# +-------------+----------+
# Crystal Event
# 5a2372f1365e003e01a04980
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.50E-02 |
# |          T0 | 5.70E+00 |
# |          R0 | 3.55E+00 |
# +-------------+----------+
# Crystal Event
# 5a2373a1365e003e01a04981
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 5.78E+00 |
# |          R0 | 3.02E+00 |
# +-------------+----------+
# Crystal Event
# 5a237453365e003e01a04982
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 5.81E+00 |
# |          R0 | 3.10E+00 |
# +-------------+----------+
# Crystal Event
# 5a237505365e003e01a04983
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 5.54E+00 |
# |          R0 | 2.93E+00 |
# +-------------+----------+
# Crystal Event
# 5a2375b5365e003e01a04984
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 5.31E+00 |
# |          R0 | 2.49E+00 |
# +-------------+----------+
# Crystal Event
# 5a237662365e003e01a04985
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 5.82E+00 |
# |          R0 | 3.46E+00 |
# +-------------+----------+
# Crystal Event
# 5a237710365e003e01a04986
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 5.46E+00 |
# |          R0 | 3.29E+00 |
# +-------------+----------+
# Crystal Event
# 5a2377bf365e003e01a04987
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 5.01E+00 |
# |          R0 | 2.83E+00 |
# +-------------+----------+
# Crystal Event
# 5a23786c365e003e01a04988
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 6.10E+00 |
# |          R0 | 2.52E+00 |
# +-------------+----------+
# Crystal Event
# 5a23791a365e003e01a04989
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.55E-02 |
# |          T0 | 5.46E+00 |
# |          R0 | 2.54E+00 |
# +-------------+----------+
# Crystal Event
# 5a2379c8365e003e01a0498a
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 5.60E+00 |
# |          R0 | 3.01E+00 |
# +-------------+----------+
# Crystal Event
# 5a237a76365e003e01a0498b
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 4.94E+00 |
# |          R0 | 2.74E+00 |
# +-------------+----------+
# Crystal Event
# 5a237b24365e003e01a0498c
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 5.13E+00 |
# |          R0 | 2.64E+00 |
# +-------------+----------+
# Crystal Event
# 5a237bd1365e003e01a0498d
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 5.69E+00 |
# |          R0 | 3.90E+00 |
# +-------------+----------+
# Crystal Event
# 5a237c7e365e003e01a0498e
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 5.94E+00 |
# |          R0 | 2.81E+00 |
# +-------------+----------+
# Crystal Event
# 5a237d29365e003e01a0498f
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 5.09E+00 |
# |          R0 | 3.56E+00 |
# +-------------+----------+
# Crystal Event
# 5a237dd3365e003e01a04990
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 6.13E+00 |
# |          R0 | 2.22E+00 |
# +-------------+----------+
# Crystal Event
# 5a237e81365e003e01a04991
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 5.37E+00 |
# |          R0 | 3.03E+00 |
# +-------------+----------+
# Crystal Event
# 5a237f30365e003e01a04992
# +-------------+----------+
# |        Name |    Value |
# +-------------+----------+
# | Temperature | 1.60E-02 |
# |          T0 | 5.31E+00 |
# |          R0 | 2.39E+00 |
# +-------------+----------+
# Crystal Event
# 5a237fdc365e003e01a04993
